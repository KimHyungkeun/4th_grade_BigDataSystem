# %%
peopleDF = spark.read.parquet("/FileStore/tables/people-10m.parquet")
peopleDF.show(5)
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">+---+---------+----------+----------+------+-------------------+-----------+------+
#  id|firstName|middleName|  lastName|gender|          birthDate|        ssn|salary|
# +---+---------+----------+----------+------+-------------------+-----------+------+
#   1|   Pennie|     Carry|Hirschmann|     F|1955-07-02 04:00:00|981-43-9345| 56172|
#   2|       An|     Amira|    Cowper|     F|1992-02-08 05:00:00|978-97-8086| 40203|
#   3|    Quyen|    Marlen|      Dome|     F|1970-10-11 04:00:00|957-57-8246| 53417|
#   4|  Coralie|  Antonina|   Marshal|     F|1990-04-11 04:00:00|963-39-4885| 94727|
#   5|   Terrie|      Wava|     Bonar|     F|1980-01-16 05:00:00|964-49-8051| 79908|
# +---+---------+----------+----------+------+-------------------+-----------+------+
# only showing top 5 rows
#
# </div>

# %%
name_lst = [c for c in peopleDF.columns if 'Name' in c]
print(name_lst)
nameDF = peopleDF[name_lst]
nameDF.show(1)

nameDF.groupBy('middleName').count().show(5)
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">[&#39;firstName&#39;, &#39;middleName&#39;, &#39;lastName&#39;]
# +---------+----------+----------+
# firstName|middleName|  lastName|
# +---------+----------+----------+
#    Pennie|     Carry|Hirschmann|
# +---------+----------+----------+
# only showing top 1 row
#
# +----------+-----+
# middleName|count|
# +----------+-----+
#      Tegan| 1309|
#       Reta| 1277|
#   Julianne| 1260|
#      Sandi| 1233|
#    Susanna| 1255|
# +----------+-----+
# only showing top 5 rows
#
# </div>

# %%
firstName = peopleDF.select('firstName').distinct()
print(firstName.count())
sortingDF = firstName.orderBy('firstName', ascending=False)
sortingDF.show(5)
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">5113
# +---------+
# firstName|
# +---------+
#     Zulma|
#    Zulema|
#      Zula|
#   Zoraida|
#      Zora|
# +---------+
# only showing top 5 rows
#
# </div>

# %%
from pyspark.sql.functions import year, col
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
dordonDF = peopleDF.\
            select(year('birthDate').alias("birthYear"), "firstName").\
            filter((col("firstName")=='Donna') | (col("firstName")=='Dorothy')).\
            filter("gender == 'F'").\
            groupBy('birthYear','firstName').\
            count().orderBy('birthYear').show(5)
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">+---------+---------+-----+
# birthYear|firstName|count|
# +---------+---------+-----+
#      1952|    Donna|   24|
#      1952|  Dorothy|   21|
#      1953|    Donna|   37|
#      1953|  Dorothy|   38|
#      1954|  Dorothy|   29|
# +---------+---------+-----+
# only showing top 5 rows
#
# </div>

# %%
dordonDF = peopleDF.\
            select(year('birthDate').alias("birthYear"), "firstName").\
            filter((col("firstName")=='Donna') | (col("firstName")=='Dorothy')).\
            filter("gender == 'F'").\
            filter(year('birthDate') >= "1990").\
            groupBy('birthYear','firstName').\
            count().orderBy('birthYear')
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
display(dordonDF)
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>birthYear</th><th>firstName</th><th>count</th></tr></thead><tbody><tr><td>1990</td><td>Donna</td><td>24</td></tr><tr><td>1990</td><td>Dorothy</td><td>29</td></tr><tr><td>1991</td><td>Dorothy</td><td>25</td></tr><tr><td>1991</td><td>Donna</td><td>27</td></tr><tr><td>1992</td><td>Dorothy</td><td>39</td></tr><tr><td>1992</td><td>Donna</td><td>30</td></tr><tr><td>1993</td><td>Donna</td><td>22</td></tr><tr><td>1993</td><td>Dorothy</td><td>28</td></tr><tr><td>1994</td><td>Donna</td><td>26</td></tr><tr><td>1994</td><td>Dorothy</td><td>21</td></tr><tr><td>1995</td><td>Dorothy</td><td>26</td></tr><tr><td>1995</td><td>Donna</td><td>33</td></tr><tr><td>1996</td><td>Dorothy</td><td>19</td></tr><tr><td>1996</td><td>Donna</td><td>23</td></tr><tr><td>1997</td><td>Donna</td><td>36</td></tr><tr><td>1997</td><td>Dorothy</td><td>24</td></tr><tr><td>1998</td><td>Donna</td><td>28</td></tr><tr><td>1998</td><td>Dorothy</td><td>33</td></tr><tr><td>1999</td><td>Donna</td><td>22</td></tr><tr><td>1999</td><td>Dorothy</td><td>25</td></tr><tr><td>2000</td><td>Dorothy</td><td>4</td></tr><tr><td>2000</td><td>Donna</td><td>2</td></tr></tbody></table></div>

# %%
valuesA = [('tom', 70), ('bob', 100), ('sam', 60), ('lee', 85), ('jun', 75)]
valuesB = [('tom', 55), ('sam', 88), ('kim', 90), ('jun', 67), ('choi', 95)]
mathS_df = spark.createDataFrame(valuesA, ['name', 'score'])
englishS_df = spark.createDataFrame(valuesB, ['name', 'score'])
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
mathS_df.show()
englishS_df.show()
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">+----+-----+
# name|score|
# +----+-----+
#  tom|   70|
#  bob|  100|
#  sam|   60|
#  lee|   85|
#  jun|   75|
# +----+-----+
#
# +----+-----+
# name|score|
# +----+-----+
#  tom|   55|
#  sam|   88|
#  kim|   90|
#  jun|   67|
# choi|   95|
# +----+-----+
#
# </div>

# %%
mathS_df = mathS_df.withColumnRenamed('score', 'math score')
englishS_df = englishS_df.withColumnRenamed('score', 'english score')

join1 = mathS_df.join(englishS_df, mathS_df.name == englishS_df.name)
join1.show()
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">+----+----------+----+-------------+
# name|math score|name|english score|
# +----+----------+----+-------------+
#  jun|        75| jun|           67|
#  tom|        70| tom|           55|
#  sam|        60| sam|           88|
# +----+----------+----+-------------+
#
# </div>

# %%
mathS_df = mathS_df.withColumnRenamed('score', 'math score')
englishS_df = englishS_df.withColumnRenamed('score', 'english score')

join2 = mathS_df.join(englishS_df, mathS_df.name == englishS_df.name, how='right')\
                .filter(mathS_df.name.isNull())
join2.show()
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">+----+----------+----+-------------+
# name|math score|name|english score|
# +----+----------+----+-------------+
# null|      null|choi|           95|
# null|      null| kim|           90|
# +----+----------+----+-------------+
#
# </div>

# %%
from pyspark.sql.functions import count, desc
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
top10MaleFirstNameDF = peopleDF.\
                        select("firstName").\
                        filter("gender = 'M'").\
                        groupBy("firstName").\
                        agg(count(col('firstName')).alias('total')).\
                        orderBy(desc('total')).\
                        limit(10)

top10MaleFirstNameDF.show(5)
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">+---------+-----+
# firstName|total|
# +---------+-----+
#   Marcelo| 4197|
#  Reynaldo| 4193|
#   Jeffrey| 4177|
#    Sammie| 4170|
#      Troy| 4167|
# +---------+-----+
# only showing top 5 rows
#
# </div>

# %%
top10MaleFirstNameDF.createOrReplaceTempView("top10MaleFirstName")
resultsDF = spark.sql("select * from top10MaleFirstName order by FirstName")
display(resultsDF)
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>firstName</th><th>total</th></tr></thead><tbody><tr><td>Darin</td><td>4166</td></tr><tr><td>Fritz</td><td>4157</td></tr><tr><td>Jeffrey</td><td>4177</td></tr><tr><td>Jess</td><td>4153</td></tr><tr><td>Marcelo</td><td>4197</td></tr><tr><td>Reynaldo</td><td>4193</td></tr><tr><td>Sammie</td><td>4170</td></tr><tr><td>Tomas</td><td>4161</td></tr><tr><td>Troy</td><td>4167</td></tr><tr><td>Wyatt</td><td>4159</td></tr></tbody></table></div>
