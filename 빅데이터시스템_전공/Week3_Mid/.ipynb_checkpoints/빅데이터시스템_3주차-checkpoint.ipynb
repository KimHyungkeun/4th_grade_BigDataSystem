# %%
import numpy as np
import matplotlib.pyplot as plt
N=500
X=2*np.random.rand(500,1) #uniform distribution
y=4+ 3*X +np.random.randn(500,1) #standard normal distribution

print(X.shape)
print(y.shape)
print(max(X))
print(min(X))
print(max(y))
print(min(y))
# Out:
# (500, 1)
# (500, 1)
# [1.99476775]
# [0.00069035]
# [11.3959723]
# [2.16591379]

# %%
plt.figure(figsize=(10,10))
plt.scatter(X,y)
plt.title("Linear Regression Data")
plt.xlabel("x")
plt.ylabel("y")
plt.show()

# %%
theta1 = 3
theta0 = 4
theta = np.array([[theta1, theta0]]).T
print(thetas)
# Out:
# [array([[3],
#        [4]]), array([[2.9837916 ],
#        [3.98128942]]), array([[2.98830568],
#        [3.98023889]]), array([[2.99025671],
#        [3.97740073]]), array([[2.99232152],
#        [3.97498199]]), array([[2.99420704],
#        [3.97271467]]), array([[2.99595887],
#        [3.97061492]]), array([[2.997583  ],
#        [3.96866745]]), array([[2.99908913],
#        [3.96686156]]), array([[3.00048579],
#        [3.96518691]]), array([[3.00178095],
#        [3.96363397]]), array([[3.00298198],
#        [3.96219389]]), array([[3.00409573],
#        [3.96085848]]), array([[3.00512852],
#        [3.95962012]]), array([[3.00608626],
#        [3.95847176]]), array([[3.00697439],
#        [3.95740686]]), array([[3.00779797],
#        [3.95641936]]), array([[3.0085617 ],
#        [3.95550363]]), array([[3.00926992],
#        [3.95465445]]), array([[3.00992667],
#        [3.95386698]]), array([[3.01053569],
#        [3.95313675]]), array([[3.01110045],
#        [3.95245959]]), array([[3.01162416],
#        [3.95183164]]), array([[3.01210981],
#        [3.95124933]]), array([[3.01256016],
#        [3.95070934]]), array([[3.01297778],
#        [3.9502086 ]]), array([[3.01336505],
#        [3.94974425]]), array([[3.01372418],
#        [3.94931364]]), array([[3.0140572 ],
#        [3.94891434]]), array([[3.01436602],
#        [3.94854405]]), array([[3.0146524 ],
#        [3.94820067]]), array([[3.01491796],
#        [3.94788225]]), array([[3.01516423],
#        [3.94758698]]), array([[3.01539259],
#        [3.94731316]]), array([[3.01560436],
#        [3.94705924]]), array([[3.01580074],
#        [3.94682378]]), array([[3.01598284],
#        [3.94660543]]), array([[3.01615171],
#        [3.94640295]]), array([[3.01630831],
#        [3.94621518]]), array([[3.01645352],
#        [3.94604107]]), array([[3.01658819],
#        [3.9458796 ]]), array([[3.01671306],
#        [3.94572987]]), array([[3.01682886],
#        [3.94559102]]), array([[3.01693624],
#        [3.94546227]]), array([[3.01703582],
#        [3.94534287]]), array([[3.01712817],
#        [3.94523215]]), array([[3.0172138 ],
#        [3.94512947]]), array([[3.0172932 ],
#        [3.94503426]]), array([[3.01736684],
#        [3.94494597]]), array([[3.01743512],
#        [3.9448641 ]]), array([[3.01749845],
#        [3.94478817]]), array([[3.01755716],
#        [3.94471776]]), array([[3.01761162],
#        [3.94465247]]), array([[3.01766211],
#        [3.94459193]]), array([[3.01770894],
#        [3.94453579]]), array([[3.01775236],
#        [3.94448372]]), array([[3.01779262],
#        [3.94443544]]), array([[3.01782996],
#        [3.94439067]]), array([[3.01786459],
#        [3.94434915]]), array([[3.0178967 ],
#        [3.94431065]]), array([[3.01792647],
#        [3.94427495]]), array([[3.01795408],
#        [3.94424184]]), array([[3.01797969],
#        [3.94421114]]), array([[3.01800343],
#        [3.94418267]]), array([[3.01802545],
#        [3.94415627]]), array([[3.01804587],
#        [3.94413179]]), array([[3.0180648 ],
#        [3.94410909]]), array([[3.01808236],
#        [3.94408804]]), array([[3.01809864],
#        [3.94406851]]), array([[3.01811374],
#        [3.94405041]]), array([[3.01812774],
#        [3.94403362]]), array([[3.01814073],
#        [3.94401805]]), array([[3.01815277],
#        [3.94400362]]), array([[3.01816393],
#        [3.94399023]]), array([[3.01817429],
#        [3.94397782]]), array([[3.01818389],
#        [3.9439663 ]]), array([[3.01819279],
#        [3.94395563]]), array([[3.01820105],
#        [3.94394573]]), array([[3.0182087 ],
#        [3.94393655]]), array([[3.0182158 ],
#        [3.94392804]]), array([[3.01822239],
#        [3.94392014]]), array([[3.01822849],
#        [3.94391282]]), array([[3.01823415],
#        [3.94390603]]), array([[3.0182394 ],
#        [3.94389974]]), array([[3.01824427],
#        [3.9438939 ]]), array([[3.01824879],
#        [3.94388849]]), array([[3.01825297],
#        [3.94388347]]), array([[3.01825685],
#        [3.94387881]]), array([[3.01826045],
#        [3.9438745 ]]), array([[3.01826379],
#        [3.94387049]]), array([[3.01826689],
#        [3.94386678]]), array([[3.01826976],
#        [3.94386334]]), array([[3.01827242],
#        [3.94386015]]), array([[3.01827489],
#        [3.94385719]]), array([[3.01827718],
#        [3.94385444]]), array([[3.0182793],
#        [3.9438519]]), array([[3.01828127],
#        [3.94384954]]), array([[3.0182831 ],
#        [3.94384735]]), array([[3.01828479],
#        [3.94384532]]), array([[3.01828636],
#        [3.94384343]]), array([[3.01828782],
#        [3.94384169]])]

# %%
oneColumns = np.full((N,1),1)
print(oneColumns.shape)
X1 = np.column_stack((X,oneColumns))
print(X1.shape)
print(X1[:10,:])
# Out:
# (500, 1)
# (500, 2)
# [[0.63614795 1.        ]
#  [0.29544881 1.        ]
#  [1.16722356 1.        ]
#  [1.43995297 1.        ]
#  [1.75838788 1.        ]
#  [1.58829468 1.        ]
#  [0.37668345 1.        ]
#  [0.00734891 1.        ]
#  [0.7443741  1.        ]
#  [0.31447958 1.        ]]

# %%
predictions = np.matmul(X1, theta)
print(predictions.shape)
plt.figure(figsize=(10,10))
plt.scatter(X,y)
plt.plot(X, predictions, color = "red")
plt.title("Linear Regression Data")
plt.xlabel("x")
plt.ylabel("y")
plt.show()
# Out:
# (500, 1)

# %%
a = np.array([[1],[2],[3]])
b = np.array([[2],[4],[1]])
c = a - b
print(a)
print(b)
print(c)
d = np.square(c)
print(d)
print(np.sum(d))

print(X1.shape)
print(X1.shape[0])
print(y.shape)
print(predictions.shape)

def cost(X,y,theta) :
    m = X.shape[0]
    predictions = np.matmul(X, theta)
    diff = predictions - y
    cost = (1/2*m)*np.sum(np.square(diff))
    return cost

print(cost(X1,y,theta))
# Out:
# [[1]
#  [2]
#  [3]]
# [[2]
#  [4]
#  [1]]
# [[-1]
#  [-2]
#  [ 2]]
# [[1]
#  [4]
#  [4]]
# 9
# (500, 2)
# 500
# (500, 1)
# (500, 1)
# 115963.89549602724

# %%
x = np.array([[10,1], [12,1], [20,1]])
error = np.array([[-1],[1],[2]])
print(x)
print(error)
print(x.T)
delta = np.matmul(x.T, error)
print(delta)
# Out:
# [[10  1]
#  [12  1]
#  [20  1]]
# [[-1]
#  [ 1]
#  [ 2]]
# [[10 12 20]
#  [ 1  1  1]]
# [[42]
#  [ 2]]

# %%
a= np.array([[10],[20]])
print(a)
b = np.array([[42],[2]])
c = a - 0.4*b
print(c)
# Out:
# [[10]
#  [20]]
# [[-6.8]
#  [19.2]]

# %%
def linear_regression(X, theta, y, alpha) :
    m = X.shape[0]
    num_iterations = 100
    costs = []
    thetas = [theta]
    for i in range(num_iterations) :
#         print("predictions : " + str(predictions))
#         print("y : " + str(y))
        predictions = np.matmul(X1, theta)
        errors = predictions - y
        delta = np.matmul(X.T, errors)
        
        theta = theta - (alpha/m)*delta
        cost1 = cost(X,y,theta)
        costs.append(cost1)
        thetas.append(theta)
    return costs, thetas

costs, thetas = linear_regression(X1, theta, y, 0.5)
print(len(costs), len(thetas))
plt.plot(costs)
# Out:
# 100 101

# %%
initialTheta = thetas[0]
print(initialTheta)
finalTheta = thetas[-1]
print(finalTheta)
prediction1 = np.matmul(X1, initialTheta)
prediction2 = np.matmul(X1, finalTheta)
# Out:
# [[3]
#  [4]]
# [[2.91165525]
#  [4.09579056]]

# %%
plt.figure(figsize=(10,10))
plt.scatter(X,y)
plt.plot(X, prediction1, color = "red")
plt.plot(X, prediction2, color = "blue")
plt.title("Linear Regression Data")
plt.xlabel("x")
plt.ylabel("y")
plt.show()
