# %%
text_file = sc.textFile("/FileStore/tables/test1.txt")
text_file.collect()
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">Out[3]: [&#39;Apache Spark Examples.&#39;,
#  &#39;These examples give a quick overview of the Spark API. &#39;,
#  &#39;Spark is built on the concept of distributed datasets, which contain arbitrary Java or Python objects. You create a dataset from external data, then apply parallel operations to it. The building block of the Spark API is its RDD API. In the RDD API, there are two types of operations: transformations, which define a new dataset based on previous ones, and actions, which kick off a job to execute on a cluster. On top of Spark’s RDD API, high level APIs are provided, e.g. DataFrame API and Machine Learning API. These high level APIs provide a concise way to conduct certain data operations. In this page, we will show examples using RDD API as well as examples using high level APIs.&#39;]</div>

# %%
string = "this is a test"
string.split(" ")
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">Out[4]: [&#39;this&#39;, &#39;is&#39;, &#39;a&#39;, &#39;test&#39;]</div>

# %%
data1 = text_file.map(lambda line : line.split(" "))
data1.take(2)
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">Out[6]: [[&#39;Apache&#39;, &#39;Spark&#39;, &#39;Examples.&#39;],
#  [&#39;These&#39;,
#   &#39;examples&#39;,
#   &#39;give&#39;,
#   &#39;a&#39;,
#   &#39;quick&#39;,
#   &#39;overview&#39;,
#   &#39;of&#39;,
#   &#39;the&#39;,
#   &#39;Spark&#39;,
#   &#39;API.&#39;,
#   &#39;&#39;]]</div>

# %%
data2 = text_file.flatMap(lambda line : line.split(" "))
data2.take(10)
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">Out[8]: [&#39;Apache&#39;,
#  &#39;Spark&#39;,
#  &#39;Examples.&#39;,
#  &#39;These&#39;,
#  &#39;examples&#39;,
#  &#39;give&#39;,
#  &#39;a&#39;,
#  &#39;quick&#39;,
#  &#39;overview&#39;,
#  &#39;of&#39;]</div>

# %%
data3 = data2.map(lambda word : (word, 1))
data3.take(10)
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">Out[9]: [(&#39;Apache&#39;, 1),
#  (&#39;Spark&#39;, 1),
#  (&#39;Examples.&#39;, 1),
#  (&#39;These&#39;, 1),
#  (&#39;examples&#39;, 1),
#  (&#39;give&#39;, 1),
#  (&#39;a&#39;, 1),
#  (&#39;quick&#39;, 1),
#  (&#39;overview&#39;, 1),
#  (&#39;of&#39;, 1)]</div>

# %%
data4 = data3.reduceByKey(lambda a,b : a+b)
data4.take(10)
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">Out[10]: [(&#39;Apache&#39;, 1),
#  (&#39;Spark&#39;, 4),
#  (&#39;These&#39;, 2),
#  (&#39;examples&#39;, 3),
#  (&#39;give&#39;, 1),
#  (&#39;quick&#39;, 1),
#  (&#39;overview&#39;, 1),
#  (&#39;of&#39;, 5),
#  (&#39;&#39;, 1),
#  (&#39;is&#39;, 2)]</div>

# %%
data5 = data4.map(lambda pair : (pair[1], pair[0]))
data5.take(10)
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">Out[11]: [(1, &#39;Apache&#39;),
#  (4, &#39;Spark&#39;),
#  (2, &#39;These&#39;),
#  (3, &#39;examples&#39;),
#  (1, &#39;give&#39;),
#  (1, &#39;quick&#39;),
#  (1, &#39;overview&#39;),
#  (5, &#39;of&#39;),
#  (1, &#39;&#39;),
#  (2, &#39;is&#39;)]</div>

# %%
data6 = data5.sortByKey(ascending=False)
data6.take(10)
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">Out[12]: [(6, &#39;a&#39;),
#  (5, &#39;of&#39;),
#  (4, &#39;Spark&#39;),
#  (4, &#39;the&#39;),
#  (4, &#39;RDD&#39;),
#  (3, &#39;examples&#39;),
#  (3, &#39;high&#39;),
#  (3, &#39;API.&#39;),
#  (3, &#39;on&#39;),
#  (3, &#39;which&#39;)]</div>

# %%
text_file = sc.textFile("/FileStore/tables/test1.txt")
counts = text_file.flatMap(lambda line : line.split(" "))\
                  .map(lambda word : (word, 1))\
                  .reduceByKey(lambda a, b : a+b)\
                  .map(lambda pair : (pair[1], pair[0]))\
                  .sortByKey(ascending=False)
counts.saveAsTextFile("count")
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
text_file = sc.textFile("/FileStore/tables/test1.txt")
text_file.collect()
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">Out[24]: [&#39;Apache Spark Examples.&#39;,
#  &#39;These examples give a quick overview of the Spark API. &#39;,
#  &#39;Spark is built on the concept of distributed datasets, which contain arbitrary Java or Python objects. You create a dataset from external data, then apply parallel operations to it. The building block of the Spark API is its RDD API. In the RDD API, there are two types of operations: transformations, which define a new dataset based on previous ones, and actions, which kick off a job to execute on a cluster. On top of Spark’s RDD API, high level APIs are provided, e.g. DataFrame API and Machine Learning API. These high level APIs provide a concise way to conduct certain data operations. In this page, we will show examples using RDD API as well as examples using high level APIs.&#39;]</div>

# %%
lineLengths = text_file.map(lambda s : len(s))
lineLengths.collect()
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">Out[25]: [22, 55, 686]</div>

# %%
totalLength = lineLengths.reduce(lambda a, b : a+b)
totalLength
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">Out[26]: 763</div>

# %%
text_file = sc.textFile("/FileStore/tables/test2.txt")
lines = text_file.filter(lambda line : "line" in line)
lines.collect()
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">Out[28]: [&#39;This is a first line.&#39;, &#39;This is a second line.&#39;, &#39;This is the last line.&#39;]</div>

# %%
lines = text_file.filter(lambda line : "last" in line)
lines.collect()
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">Out[29]: [&#39;This is the last line.&#39;]</div>

# %%
data = sc.textFile("/FileStore/tables/test3.txt")
data.collect()
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">Out[30]: [&#39;Carlo,5,3,3,4&#39;,
#  &#39;Mokhtar,2,5,5,3&#39;,
#  &#39;Jacques,4,2,4,5&#39;,
#  &#39;Braden,5,3,2,5&#39;,
#  &#39;Chris,5,4,5,1&#39;]</div>

# %%
data1 = data.map(lambda l : l.split(","))
data1.collect()
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">Out[31]: [[&#39;Carlo&#39;, &#39;5&#39;, &#39;3&#39;, &#39;3&#39;, &#39;4&#39;],
#  [&#39;Mokhtar&#39;, &#39;2&#39;, &#39;5&#39;, &#39;5&#39;, &#39;3&#39;],
#  [&#39;Jacques&#39;, &#39;4&#39;, &#39;2&#39;, &#39;4&#39;, &#39;5&#39;],
#  [&#39;Braden&#39;, &#39;5&#39;, &#39;3&#39;, &#39;2&#39;, &#39;5&#39;],
#  [&#39;Chris&#39;, &#39;5&#39;, &#39;4&#39;, &#39;5&#39;, &#39;1&#39;]]</div>

# %%
data2 = data1.map(lambda item : (item[0], item[1]+item[2]+item[3]+item[4]))
data2.collect()
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">Out[32]: [(&#39;Carlo&#39;, &#39;5334&#39;),
#  (&#39;Mokhtar&#39;, &#39;2553&#39;),
#  (&#39;Jacques&#39;, &#39;4245&#39;),
#  (&#39;Braden&#39;, &#39;5325&#39;),
#  (&#39;Chris&#39;, &#39;5451&#39;)]</div>

# %%
data2 = data1.map(lambda item : (item[0], int(item[1])+int(item[2])+int(item[3])+int(item[4])))
data2.collect()
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">Out[33]: [(&#39;Carlo&#39;, 15),
#  (&#39;Mokhtar&#39;, 15),
#  (&#39;Jacques&#39;, 15),
#  (&#39;Braden&#39;, 15),
#  (&#39;Chris&#39;, 15)]</div>

# %%
data3 = data2.map(lambda item : (item[0], item[1], item[1]/4))
data3.collect()
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">Out[34]: [(&#39;Carlo&#39;, 15, 3.75),
#  (&#39;Mokhtar&#39;, 15, 3.75),
#  (&#39;Jacques&#39;, 15, 3.75),
#  (&#39;Braden&#39;, 15, 3.75),
#  (&#39;Chris&#39;, 15, 3.75)]</div>

# %%
inputrdd = sc.parallelize([["maths", 50], ["maths", 60], ["english", 65], ["english", 85]])
inputrdd.collect()
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">Out[35]: [[&#39;maths&#39;, 50], [&#39;maths&#39;, 60], [&#39;english&#39;, 65], [&#39;english&#39;, 85]]</div>

# %%
mapped = inputrdd.mapValues(lambda mark : (mark, 1))
mapped.collect()
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">Out[36]: [(&#39;maths&#39;, (50, 1)),
#  (&#39;maths&#39;, (60, 1)),
#  (&#39;english&#39;, (65, 1)),
#  (&#39;english&#39;, (85, 1))]</div>

# %%
reduced = mapped.reduceByKey(lambda x, y : (x[0]+y[0], x[1]+y[1]))
reduced.collect()
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">Out[37]: [(&#39;english&#39;, (150, 2)), (&#39;maths&#39;, (110, 2))]</div>

# %%
average = reduced.map(lambda x : (x[0], x[1][0]/x[1][1]))
average.collect()
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">Out[38]: [(&#39;english&#39;, 75.0), (&#39;maths&#39;, 55.0)]</div>

# %%
mapLink = sc.parallelize([["MapR", "Baidu"], ["MapR", "Blogger"], ["Baidu", "MapR"], ["Blogger", "Google"], ["Blogger", "Baidu"], ["Google", "MapR"]])
links = mapLink.groupByKey()
links.collect()
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">Out[39]: [(&#39;Google&#39;, &lt;pyspark.resultiterable.ResultIterable at 0x7efe4a4bc590&gt;),
#  (&#39;MapR&#39;, &lt;pyspark.resultiterable.ResultIterable at 0x7efe4a4bc190&gt;),
#  (&#39;Baidu&#39;, &lt;pyspark.resultiterable.ResultIterable at 0x7efe4a4bc5d0&gt;),
#  (&#39;Blogger&#39;, &lt;pyspark.resultiterable.ResultIterable at 0x7efe4a4bc290&gt;)]</div>

# %%
print(list((k, list(v)) for (k,v) in links.collect()))
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">[(&#39;Google&#39;, [&#39;MapR&#39;]), (&#39;MapR&#39;, [&#39;Baidu&#39;, &#39;Blogger&#39;]), (&#39;Baidu&#39;, [&#39;MapR&#39;]), (&#39;Blogger&#39;, [&#39;Google&#39;, &#39;Baidu&#39;])]
# </div>

# %%
ranks = links.map(lambda pairs : (pairs[0], 1))
ranks.collect()
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">Out[41]: [(&#39;Google&#39;, 1), (&#39;MapR&#39;, 1), (&#39;Baidu&#39;, 1), (&#39;Blogger&#39;, 1)]</div>

# %%
cvalues = links.join(ranks)
cvalues.collect()
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">Out[42]: [(&#39;Google&#39;, (&lt;pyspark.resultiterable.ResultIterable at 0x7efe4a505710&gt;, 1)),
#  (&#39;MapR&#39;, (&lt;pyspark.resultiterable.ResultIterable at 0x7efe4a505550&gt;, 1)),
#  (&#39;Baidu&#39;, (&lt;pyspark.resultiterable.ResultIterable at 0x7efe4a505390&gt;, 1)),
#  (&#39;Blogger&#39;, (&lt;pyspark.resultiterable.ResultIterable at 0x7efe4a4a2050&gt;, 1))]</div>

# %%
print(list((k, list(v)) for (k, v) in cvalues.collect()))
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">[(&#39;Google&#39;, [&lt;pyspark.resultiterable.ResultIterable object at 0x7efe4a4ba550&gt;, 1]), (&#39;MapR&#39;, [&lt;pyspark.resultiterable.ResultIterable object at 0x7efe4a4babd0&gt;, 1]), (&#39;Baidu&#39;, [&lt;pyspark.resultiterable.ResultIterable object at 0x7efe4a4ba690&gt;, 1]), (&#39;Blogger&#39;, [&lt;pyspark.resultiterable.ResultIterable object at 0x7efe4a493310&gt;, 1])]
# </div>

# %%
print(list((k, list(v[0]), v[1]) for (k, v) in cvalues.collect()))
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">[(&#39;Google&#39;, [&#39;MapR&#39;], 1), (&#39;MapR&#39;, [&#39;Baidu&#39;, &#39;Blogger&#39;], 1), (&#39;Baidu&#39;, [&#39;MapR&#39;], 1), (&#39;Blogger&#39;, [&#39;Google&#39;, &#39;Baidu&#39;], 1)]
# </div>

# %%
def computeContribs(urls, rank) :
  num_urls = len(urls)
  for url in urls :
    yield(url, rank / num_urls)
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
a = computeContribs([1,2,3], 1)
for i in a :
  print(i)
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">(1, 0.3333333333333333)
# (2, 0.3333333333333333)
# (3, 0.3333333333333333)
# </div>

# %%
contribs = links.join(ranks).flatMap(
              lambda url_urls_rank : computeContribs(url_urls_rank[1][0], url_urls_rank[1][1]))
contribs.collect()
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">Out[48]: [(&#39;MapR&#39;, 1.0),
#  (&#39;Baidu&#39;, 0.5),
#  (&#39;Blogger&#39;, 0.5),
#  (&#39;MapR&#39;, 1.0),
#  (&#39;Google&#39;, 0.5),
#  (&#39;Baidu&#39;, 0.5)]</div>

# %%
new_rank = contribs.reduceByKey(lambda a,b : a+b).collect()
print(new_rank)
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">[(&#39;Google&#39;, 0.5), (&#39;MapR&#39;, 2.0), (&#39;Baidu&#39;, 1.0), (&#39;Blogger&#39;, 0.5)]
# </div>

# %%
new_rank1 = contribs.reduceByKey(lambda x,y : x+y).mapValues(lambda rank : 0.15 + 0.85 * rank).collect()
print(new_rank1)
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">[(&#39;Google&#39;, 0.575), (&#39;MapR&#39;, 1.8499999999999999), (&#39;Baidu&#39;, 1.0), (&#39;Blogger&#39;, 0.575)]
# </div>
