# %%
text_file = sc.textFile("/FileStore/tables/spark.txt")
data = text_file.flatMap(lambda l : l.split())\
                .map(lambda word : (word, 1))\
                .reduceByKey(lambda x, y : x+y)\
                .filter(lambda pair : pair[1] >= 2)
data.collect()
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">Out[2]: [(&#39;Spark&#39;, 4), (&#39;is&#39;, 3), (&#39;a&#39;, 2), (&#39;This&#39;, 2)]</div>

# %%
data = data.map(lambda p : (p[1], p[0]))\
            .sortByKey(ascending=False)
data.collect()
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">Out[3]: [(4, &#39;Spark&#39;), (3, &#39;is&#39;), (2, &#39;a&#39;), (2, &#39;This&#39;)]</div>

# %%
mapLink = sc.parallelize([["PageA", "PageB"], ["PageA", "PageC"], ["PageB", "PageC"], ["PageC", "PageA"], ["PageD","PageC"]])
links = mapLink.groupByKey()
print(list((k, list(v)) for (k,v) in links.collect()))
ranks = links.map(lambda pairs : (pairs[0], 1))
print(ranks.collect())
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">[(&#39;PageA&#39;, [&#39;PageB&#39;, &#39;PageC&#39;]), (&#39;PageB&#39;, [&#39;PageC&#39;]), (&#39;PageC&#39;, [&#39;PageA&#39;]), (&#39;PageD&#39;, [&#39;PageC&#39;])]
# [(&#39;PageA&#39;, 1), (&#39;PageB&#39;, 1), (&#39;PageC&#39;, 1), (&#39;PageD&#39;, 1)]
# </div>

# %%
def computeContribs(urls, rank) :
  num_urls = len(urls)
  for url in urls :
    yield (url, rank / num_urls)

contribs = links.join(ranks).flatMap(
              lambda url_urls_rank : computeContribs(url_urls_rank[1][0], url_urls_rank[1][1]))
contribs.collect()
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">Out[9]: [(&#39;PageB&#39;, 0.5),
#  (&#39;PageC&#39;, 0.5),
#  (&#39;PageC&#39;, 1.0),
#  (&#39;PageC&#39;, 1.0),
#  (&#39;PageA&#39;, 1.0)]</div>

# %%
new_rank = contribs.reduceByKey(lambda x, y : x+y).mapValues(lambda rank : 0.15 + 0.85*rank).collect()
print(new_rank)
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">[(&#39;PageB&#39;, 0.575), (&#39;PageA&#39;, 1.0), (&#39;PageC&#39;, 2.275)]
# </div>
