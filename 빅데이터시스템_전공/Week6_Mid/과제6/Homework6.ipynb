# %%
x = sc.parallelize([1,2,3])
y = x.map(lambda x : (x, x*2))
print(y.collect())
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">[(1, 2), (2, 4), (3, 6)]
# </div>

# %%
x = sc.parallelize([1,2,3,4,5])
y = x.filter(lambda x : x % 2 == 0)
print(x.collect())
print(y.collect())
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">[1, 2, 3, 4, 5]
# [2, 4]
# </div>

# %%
text = 'this is test that is not test this test is easy'.split()

x = sc.parallelize(text)
map_x = x.map(lambda word : (word, 1))
reduce = map_x.reduceByKey(lambda x, y : x+y)\
          .filter(lambda x : x[1] >= 3).collect()
print(reduce)
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">[(&#39;is&#39;, 3), (&#39;test&#39;, 3)]
# </div>

# %%
text = 'this is test that is not test this test is easy'.split()

x = sc.parallelize(text)
map_x = x.map(lambda word : (word, 1))
group = map_x.groupByKey().map(lambda x : (x[0], sum(x[1])))\
          .filter(lambda x : x[1] >= 3).collect()
print(group)
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">[(&#39;is&#39;, 3), (&#39;test&#39;, 3)]
# </div>
