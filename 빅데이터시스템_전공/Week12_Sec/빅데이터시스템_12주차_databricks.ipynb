# %%
peopleDF = spark.read.parquet("/FileStore/tables/people-10m.parquet")
peopleDF.show(5)
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">+---+---------+----------+----------+------+-------------------+-----------+------+
#  id|firstName|middleName|  lastName|gender|          birthDate|        ssn|salary|
# +---+---------+----------+----------+------+-------------------+-----------+------+
#   1|   Pennie|     Carry|Hirschmann|     F|1955-07-02 04:00:00|981-43-9345| 56172|
#   2|       An|     Amira|    Cowper|     F|1992-02-08 05:00:00|978-97-8086| 40203|
#   3|    Quyen|    Marlen|      Dome|     F|1970-10-11 04:00:00|957-57-8246| 53417|
#   4|  Coralie|  Antonina|   Marshal|     F|1990-04-11 04:00:00|963-39-4885| 94727|
#   5|   Terrie|      Wava|     Bonar|     F|1980-01-16 05:00:00|964-49-8051| 79908|
# +---+---------+----------+----------+------+-------------------+-----------+------+
# only showing top 5 rows
#
# </div>

# %%
from pyspark.sql.functions import abs, col, round
peopleWithFixedSalariesDF = peopleDF.select("firstName", "middleName", "lastName", "gender", "ssn", abs(col("salary")).alias("salary"))
peopleWithFixedSalariesDF.count()
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">Out[8]: 10000000</div>

# %%
peopleWithFixedSalariesDF.show(3)
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">+---------+----------+----------+------+-----------+------+
# firstName|middleName|  lastName|gender|        ssn|salary|
# +---------+----------+----------+------+-----------+------+
#    Pennie|     Carry|Hirschmann|     F|981-43-9345| 56172|
#        An|     Amira|    Cowper|     F|978-97-8086| 40203|
#     Quyen|    Marlen|      Dome|     F|957-57-8246| 53417|
# +---------+----------+----------+------+-----------+------+
# only showing top 3 rows
#
# </div>

# %%
peopleWithFixedSalaries20DF = peopleWithFixedSalariesDF.select("*")\
                              .withColumn("salary10K", round(col("salary")/10000))\
                              .filter("salary >= 20000")
peopleWithFixedSalaries20DF.show(5)
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">+---------+----------+----------+------+-----------+------+---------+
# firstName|middleName|  lastName|gender|        ssn|salary|salary10K|
# +---------+----------+----------+------+-----------+------+---------+
#    Pennie|     Carry|Hirschmann|     F|981-43-9345| 56172|      6.0|
#        An|     Amira|    Cowper|     F|978-97-8086| 40203|      4.0|
#     Quyen|    Marlen|      Dome|     F|957-57-8246| 53417|      5.0|
#   Coralie|  Antonina|   Marshal|     F|963-39-4885| 94727|      9.0|
#    Terrie|      Wava|     Bonar|     F|964-49-8051| 79908|      8.0|
# +---------+----------+----------+------+-----------+------+---------+
# only showing top 5 rows
#
# </div>

# %%
from pyspark.sql import Row
l = [('Ankit', 25), ('Jalfaizy', 22), ('saurabh', 20), ('Bala', 26)]
rdd = sc.parallelize(l)
people = rdd.map(lambda x : Row(name=x[0], age=int(x[1])))
schemaPeople = sqlContext.createDataFrame(people)
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
people.take(3)
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">Out[13]: [Row(name=&#39;Ankit&#39;, age=25),
#  Row(name=&#39;Jalfaizy&#39;, age=22),
#  Row(name=&#39;saurabh&#39;, age=20)]</div>

# %%
schemaPeople.show(3)
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">+--------+---+
#     name|age|
# +--------+---+
#    Ankit| 25|
# Jalfaizy| 22|
#  saurabh| 20|
# +--------+---+
# only showing top 3 rows
#
# </div>

# %%
geoip_rdd = sc.textFile("/FileStore/tables/text/geoip.txt")
geoip_rdd.take(3)
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">Out[15]: [&#39;194.20.126.123,NL,Netherlands&#39;,
#  &#39;94.126.119.173,FR,France&#39;,
#  &#39;193.46.74.166,RU,Russian Federation&#39;]</div>

# %%
geoip_rdd1 = geoip_rdd\
            .map(lambda x : x.split(","))
geoip_rdd1.take(3)
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">Out[16]: [[&#39;194.20.126.123&#39;, &#39;NL&#39;, &#39;Netherlands&#39;],
#  [&#39;94.126.119.173&#39;, &#39;FR&#39;, &#39;France&#39;],
#  [&#39;193.46.74.166&#39;, &#39;RU&#39;, &#39;Russian Federation&#39;]]</div>

# %%
geoip_rdd2 = geoip_rdd1.map(lambda x : Row(ip=x[0], code=x[1], country=x[2]))
geoip_rdd2.take(3)
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">Out[17]: [Row(ip=&#39;194.20.126.123&#39;, code=&#39;NL&#39;, country=&#39;Netherlands&#39;),
#  Row(ip=&#39;94.126.119.173&#39;, code=&#39;FR&#39;, country=&#39;France&#39;),
#  Row(ip=&#39;193.46.74.166&#39;, code=&#39;RU&#39;, country=&#39;Russian Federation&#39;)]</div>

# %%
geoipDF = sqlContext.createDataFrame(geoip_rdd2)
geoipDF.show()
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">+--------------+----+------------------+
#             ip|code|           country|
# +--------------+----+------------------+
# 194.20.126.123|  NL|       Netherlands|
# 94.126.119.173|  FR|            France|
#  193.46.74.166|  RU|Russian Federation|
#  46.235.67.202|  RU|Russian Federation|
# 193.161.193.64|  RU|Russian Federation|
# +--------------+----+------------------+
#
# </div>

# %%
#RDD API
geoipDF.rdd.collect()
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">Out[19]: [Row(ip=&#39;194.20.126.123&#39;, code=&#39;NL&#39;, country=&#39;Netherlands&#39;),
#  Row(ip=&#39;94.126.119.173&#39;, code=&#39;FR&#39;, country=&#39;France&#39;),
#  Row(ip=&#39;193.46.74.166&#39;, code=&#39;RU&#39;, country=&#39;Russian Federation&#39;),
#  Row(ip=&#39;46.235.67.202&#39;, code=&#39;RU&#39;, country=&#39;Russian Federation&#39;),
#  Row(ip=&#39;193.161.193.64&#39;, code=&#39;RU&#39;, country=&#39;Russian Federation&#39;)]</div>

# %%
#RDD API
geoipDF.rdd\
  .filter(lambda x : x.country == 'Russian Federation')\
  .take(3)
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">Out[20]: [Row(ip=&#39;193.46.74.166&#39;, code=&#39;RU&#39;, country=&#39;Russian Federation&#39;),
#  Row(ip=&#39;46.235.67.202&#39;, code=&#39;RU&#39;, country=&#39;Russian Federation&#39;),
#  Row(ip=&#39;193.161.193.64&#39;, code=&#39;RU&#39;, country=&#39;Russian Federation&#39;)]</div>

# %%
#DataFrame API
geoipDF.select("ip", "country")\
  .where("country == 'Russian Federation'")\
  .show(4)
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">+--------------+------------------+
#             ip|           country|
# +--------------+------------------+
#  193.46.74.166|Russian Federation|
#  46.235.67.202|Russian Federation|
# 193.161.193.64|Russian Federation|
# +--------------+------------------+
#
# </div>

# %%
# SQL
geoipDF.createOrReplaceTempView("geoip")
spark.sql("select ip, country from geoip where country = 'Russian Federation'").show()
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">+--------------+------------------+
#             ip|           country|
# +--------------+------------------+
#  193.46.74.166|Russian Federation|
#  46.235.67.202|Russian Federation|
# 193.161.193.64|Russian Federation|
# +--------------+------------------+
#
# </div>

# %%
peopleDF.createOrReplaceTempView("People10M")
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
# %sql
select firstName, count(lastName) from people10M group by firstName limit 3
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>firstName</th><th>count(lastName)</th></tr></thead><tbody><tr><td>Alayna</td><td>1313</td></tr><tr><td>Melaine</td><td>1237</td></tr><tr><td>Faye</td><td>1350</td></tr></tbody></table></div>

# %%
import pyspark.sql.functions as f
peopleDF.groupBy("firstName").agg(f.count("lastName")).show(3)
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">+---------+---------------+
# firstName|count(lastName)|
# +---------+---------------+
#    Alayna|           1313|
#   Melaine|           1237|
#      Faye|           1350|
# +---------+---------------+
# only showing top 3 rows
#
# </div>

# %%
peopleDF.groupBy("firstName").agg(f.count('lastName').alias('lastName count')).show(3)
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">+---------+--------------+
# firstName|lastName count|
# +---------+--------------+
#    Alayna|          1313|
#   Melaine|          1237|
#      Faye|          1350|
# +---------+--------------+
# only showing top 3 rows
#
# </div>

# %%
peopleDF.groupBy('firstName').agg({'lastName':'count'}).show(3)
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">+---------+---------------+
# firstName|count(lastName)|
# +---------+---------------+
#    Alayna|           1313|
#   Melaine|           1237|
#      Faye|           1350|
# +---------+---------------+
# only showing top 3 rows
#
# </div>

# %%
peopleDF.groupBy('firstName').agg({'lastName':'count'}).withColumnRenamed('count(lastName)', 'lastName count').show(3)
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">+---------+--------------+
# firstName|lastName count|
# +---------+--------------+
#    Alayna|          1313|
#   Melaine|          1237|
#      Faye|          1350|
# +---------+--------------+
# only showing top 3 rows
#
# </div>

# %%
peopleDF.groupBy(f.length('firstName')).agg(f.count('*')).show(3)
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">+-----------------+--------+
# length(firstName)|count(1)|
# +-----------------+--------+
#                 6| 2633717|
#                 3|  428721|
#                 5| 2278227|
# +-----------------+--------+
# only showing top 3 rows
#
# </div>

# %%
peopleDF.groupBy(f.length('firstName')).count().show(3)
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">+-----------------+-------+
# length(firstName)|  count|
# +-----------------+-------+
#                 6|2633717|
#                 3| 428721|
#                 5|2278227|
# +-----------------+-------+
# only showing top 3 rows
#
# </div>

# %%
peopleDF.groupBy('firstName', f.length('firstName')).agg(f.count("*")).show(3)
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">+---------+-----------------+--------+
# firstName|length(firstName)|count(1)|
# +---------+-----------------+--------+
#   Yolonda|                7|    1283|
#     Joyce|                5|    1232|
#     Kecia|                5|    1300|
# +---------+-----------------+--------+
# only showing top 3 rows
#
# </div>

# %%
peopleDF.groupBy("firstName", f.length('firstName')).agg(f.count("*").alias('count')).show(3)
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">+---------+-----------------+-----+
# firstName|length(firstName)|count|
# +---------+-----------------+-----+
#   Yolonda|                7| 1283|
#     Joyce|                5| 1232|
#     Kecia|                5| 1300|
# +---------+-----------------+-----+
# only showing top 3 rows
#
# </div>

# %%
peopleDF.groupBy("firstName", f.length('firstName')).count().show(3)
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">+---------+-----------------+-----+
# firstName|length(firstName)|count|
# +---------+-----------------+-----+
#   Yolonda|                7| 1283|
#     Joyce|                5| 1232|
#     Kecia|                5| 1300|
# +---------+-----------------+-----+
# only showing top 3 rows
#
# </div>

# %%
peopleDF.groupBy('salary').agg(f.count('*')).show(3)
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">+------+--------+
# salary|count(1)|
# +------+--------+
#  92080|     141|
#  29814|      15|
#  43527|      68|
# +------+--------+
# only showing top 3 rows
#
# </div>

# %%
peopleDF.agg(f.min('salary'), f.max('salary'), f.avg('salary'), f.sum('salary')).show()
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">+-----------+-----------+-------------+------------+
# min(salary)|max(salary)|  avg(salary)| sum(salary)|
# +-----------+-----------+-------------+------------+
#      -26884|     180841|72633.0076033|726330076033|
# +-----------+-----------+-------------+------------+
#
# </div>

# %%
peopleDF.groupBy('firstName').agg(f.min('salary')).orderBy('firstName').show(3)
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">+---------+-----------+
# firstName|min(salary)|
# +---------+-----------+
#     Aaron|       3829|
#     Abbey|      10320|
#     Abbie|       3212|
# +---------+-----------+
# only showing top 3 rows
#
# </div>

# %%
peopleDF.groupBy('firstName', 'gender').agg(f.count('*'), f.min('salary')).orderBy('firstName').show(3)
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">+---------+------+--------+-----------+
# firstName|gender|count(1)|min(salary)|
# +---------+------+--------+-----------+
#     Aaron|     M|    4020|       3829|
#     Abbey|     F|    1273|      10320|
#     Abbie|     F|    1288|       3212|
# +---------+------+--------+-----------+
# only showing top 3 rows
#
# </div>

# %%
AaronSalary = peopleDF.filter("firstName == 'Aaron'").groupBy('salary').count().orderBy('salary')
AaronSalary.show(3)
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">+------+-----+
# salary|count|
# +------+-----+
#   3829|    1|
#   7488|    1|
#   7997|    1|
# +------+-----+
# only showing top 3 rows
#
# </div>

# %%
peopleDF.orderBy('firstName').groupBy('firstName')\
        .agg(f.count("*").alias('count'))\
        .orderBy(f.col('count').desc())\
        .show(3)
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">+---------+-----+
# firstName|count|
# +---------+-----+
#    Sammie| 5462|
#     Daryl| 5442|
#    Bobbie| 5432|
# +---------+-----+
# only showing top 3 rows
#
# </div>

# %%
peopleDF.orderBy('firstName').groupBy('firstName')\
        .agg(f.count("*").alias('count'))\
        .orderBy(f.col('count'))\
        .show(3)
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">+---------+-----+
# firstName|count|
# +---------+-----+
#  Marylynn| 1150|
#     Verna| 1154|
#   Carlena| 1159|
# +---------+-----+
# only showing top 3 rows
#
# </div>
