# %%
text_file = sc.textFile('/FileStore/tables/test1.txt')
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
# %fs ls /FileStore/tables
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>path</th><th>name</th><th>size</th></tr></thead><tbody><tr><td>dbfs:/FileStore/tables/people-10m.parquet/</td><td>people-10m.parquet/</td><td>0</td></tr><tr><td>dbfs:/FileStore/tables/test.txt</td><td>test.txt</td><td>6</td></tr><tr><td>dbfs:/FileStore/tables/test1.txt</td><td>test1.txt</td><td>769</td></tr><tr><td>dbfs:/FileStore/tables/test2.txt</td><td>test2.txt</td><td>69</td></tr><tr><td>dbfs:/FileStore/tables/test3.txt</td><td>test3.txt</td><td>78</td></tr></tbody></table></div>

# %%
text_file.collect()
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">Out[3]: [&#39;Apache Spark Examples.&#39;,
#  &#39;These examples give a quick overview of the Spark API. &#39;,
#  &#39;Spark is built on the concept of distributed datasets, which contain arbitrary Java or Python objects. You create a dataset from external data, then apply parallel operations to it. The building block of the Spark API is its RDD API. In the RDD API, there are two types of operations: transformations, which define a new dataset based on previous ones, and actions, which kick off a job to execute on a cluster. On top of Spark’s RDD API, high level APIs are provided, e.g. DataFrame API and Machine Learning API. These high level APIs provide a concise way to conduct certain data operations. In this page, we will show examples using RDD API as well as examples using high level APIs.&#39;]</div>

# %%
# Create RDD
l = [('Ankit', 25), ('Jalfaizy', 22), ('saurabh', 20), ('Bala', 26)]
rdd = sc.parallelize(l)
print(rdd.collect())
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">[(&#39;Ankit&#39;, 25), (&#39;Jalfaizy&#39;, 22), (&#39;saurabh&#39;, 20), (&#39;Bala&#39;, 26)]
# </div>

# %%
# page rank program
def computeContribs(urls, rank) :
  """Calculates URL contributions to the rank of other URLs"""
  num_urls = len(urls)
  for url in urls :
    yield(url, rank / num_urls)

mapLink = sc.parallelize([ ["MapR", "Baidu"], ["MapR", "Blogger"], ["Baidu", "MapR"], ["Blogger", "Google"], ["Blogger", "Baidu"],["Google","MapR"]])

links = mapLink.groupByKey()

ranks = links.map(lambda pairs : (pairs[0], 1))
print("initial ranks : ", ranks.collect())

for i in range(5) :
  cvalues = links.join(ranks)
  contribs = links.join(ranks).flatMap(lambda url_urls_rank : computeContribs(url_urls_rank[1][0], url_urls_rank[1][1]))
  ranks = contribs.reduceByKey(lambda x, y : x+y).mapValues(lambda rank : 0.15 + 0.85*rank)
  print("ranks(",i,"):", ranks.collect())
  print()
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">initial ranks :  [(&#39;Google&#39;, 1), (&#39;MapR&#39;, 1), (&#39;Baidu&#39;, 1), (&#39;Blogger&#39;, 1)]
# ranks( 0 ): [(&#39;Google&#39;, 0.575), (&#39;MapR&#39;, 1.8499999999999999), (&#39;Baidu&#39;, 1.0), (&#39;Blogger&#39;, 0.575)]
#
# ranks( 1 ): [(&#39;MapR&#39;, 1.4887499999999998), (&#39;Blogger&#39;, 0.9362499999999999), (&#39;Baidu&#39;, 1.1806249999999998), (&#39;Google&#39;, 0.394375)]
#
# ranks( 2 ): [(&#39;Google&#39;, 0.5479062499999999), (&#39;MapR&#39;, 1.4887499999999996), (&#39;Baidu&#39;, 1.1806249999999998), (&#39;Blogger&#39;, 0.7827187499999999)]
#
# ranks( 3 ): [(&#39;MapR&#39;, 1.6192515624999995), (&#39;Baidu&#39;, 1.1153742187499998), (&#39;Blogger&#39;, 0.7827187499999998), (&#39;Google&#39;, 0.48265546875)]
#
# ranks( 4 ): [(&#39;MapR&#39;, 1.5083252343749995), (&#39;Google&#39;, 0.48265546874999987), (&#39;Blogger&#39;, 0.8381819140624998), (&#39;Baidu&#39;, 1.1708373828124996)]
#
# </div>

# %%
from pyspark.sql import Row
l = [('Ankit', 25), ('Jalfaizy', 22), ('saurabh', 20), ('Bala', 26)]
rdd = sc.parallelize(l)
people = rdd.map(lambda x : Row(name=x[0], age=int(x[1])))
schemaPeople = sqlContext.createDataFrame(people)
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
print(type(schemaPeople))
schemaPeople.printSchema()
print(schemaPeople.collect())
print(schemaPeople.count())
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">&lt;class &#39;pyspark.sql.dataframe.DataFrame&#39;&gt;
# root
# -- name: string (nullable = true)
# -- age: long (nullable = true)
#
# [Row(name=&#39;Ankit&#39;, age=25), Row(name=&#39;Jalfaizy&#39;, age=22), Row(name=&#39;saurabh&#39;, age=20), Row(name=&#39;Bala&#39;, age=26)]
# 4
# </div>

# %%
peopleDF = spark.read.parquet("/FileStore/tables/people-10m.parquet")
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
peopleDF.printSchema() #스키마 출력
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">root
# -- id: integer (nullable = true)
# -- firstName: string (nullable = true)
# -- middleName: string (nullable = true)
# -- lastName: string (nullable = true)
# -- gender: string (nullable = true)
# -- birthDate: timestamp (nullable = true)
# -- ssn: string (nullable = true)
# -- salary: integer (nullable = true)
#
# </div>

# %%
peopleDF.show(5)
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">+---+---------+----------+----------+------+-------------------+-----------+------+
#  id|firstName|middleName|  lastName|gender|          birthDate|        ssn|salary|
# +---+---------+----------+----------+------+-------------------+-----------+------+
#   1|   Pennie|     Carry|Hirschmann|     F|1955-07-02 04:00:00|981-43-9345| 56172|
#   2|       An|     Amira|    Cowper|     F|1992-02-08 05:00:00|978-97-8086| 40203|
#   3|    Quyen|    Marlen|      Dome|     F|1970-10-11 04:00:00|957-57-8246| 53417|
#   4|  Coralie|  Antonina|   Marshal|     F|1990-04-11 04:00:00|963-39-4885| 94727|
#   5|   Terrie|      Wava|     Bonar|     F|1980-01-16 05:00:00|964-49-8051| 79908|
# +---+---------+----------+----------+------+-------------------+-----------+------+
# only showing top 5 rows
#
# </div>

# %%
peopleDF.head(5)
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">Out[10]: [Row(id=1, firstName=&#39;Pennie&#39;, middleName=&#39;Carry&#39;, lastName=&#39;Hirschmann&#39;, gender=&#39;F&#39;, birthDate=datetime.datetime(1955, 7, 2, 4, 0), ssn=&#39;981-43-9345&#39;, salary=56172),
#  Row(id=2, firstName=&#39;An&#39;, middleName=&#39;Amira&#39;, lastName=&#39;Cowper&#39;, gender=&#39;F&#39;, birthDate=datetime.datetime(1992, 2, 8, 5, 0), ssn=&#39;978-97-8086&#39;, salary=40203),
#  Row(id=3, firstName=&#39;Quyen&#39;, middleName=&#39;Marlen&#39;, lastName=&#39;Dome&#39;, gender=&#39;F&#39;, birthDate=datetime.datetime(1970, 10, 11, 4, 0), ssn=&#39;957-57-8246&#39;, salary=53417),
#  Row(id=4, firstName=&#39;Coralie&#39;, middleName=&#39;Antonina&#39;, lastName=&#39;Marshal&#39;, gender=&#39;F&#39;, birthDate=datetime.datetime(1990, 4, 11, 4, 0), ssn=&#39;963-39-4885&#39;, salary=94727),
#  Row(id=5, firstName=&#39;Terrie&#39;, middleName=&#39;Wava&#39;, lastName=&#39;Bonar&#39;, gender=&#39;F&#39;, birthDate=datetime.datetime(1980, 1, 16, 5, 0), ssn=&#39;964-49-8051&#39;, salary=79908)]</div>

# %%
print(peopleDF.count())
print(peopleDF.columns) #컬럼 출력
print(peopleDF.describe().show(5))
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">10000000
# [&#39;id&#39;, &#39;firstName&#39;, &#39;middleName&#39;, &#39;lastName&#39;, &#39;gender&#39;, &#39;birthDate&#39;, &#39;ssn&#39;, &#39;salary&#39;]
# </div>
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>

# %%
peopleDF.select('firstName','birthDate').show(5) # firstname, birthDate만 컬럼만 출력
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">+---------+-------------------+
# firstName|          birthDate|
# +---------+-------------------+
#    Pennie|1955-07-02 04:00:00|
#        An|1992-02-08 05:00:00|
#     Quyen|1970-10-11 04:00:00|
#   Coralie|1990-04-11 04:00:00|
#    Terrie|1980-01-16 05:00:00|
# +---------+-------------------+
# only showing top 5 rows
#
# </div>

# %%
peopleDF.select('gender').distinct().count() # 각 성별로 총 몇명인지 구함
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">Out[13]: 2</div>

# %%
peopleDF.filter(peopleDF['gender'] == 'F').count() # 총 인원 중 여자 수
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">Out[14]: 5187302</div>

# %%
peopleDF.filter(peopleDF.gender == 'F').count() # 총 인원 중 여자 수
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">Out[15]: 5187302</div>

# %%
peopleDF.filter("gender == 'F'").count() # 총 인원 중 여자 수
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">Out[16]: 5187302</div>

# %%
from pyspark.sql.functions import year
peopleDF.filter(year("birthDate") > "1955").count() # 날짜에서 year() 함수를 이용해 년도만 골라낸다, "1955" 말고도 1955를 해도 상관 없음
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">Out[17]: 9168285</div>

# %%
test1 = peopleDF.select("firstName").filter("'gender'='M'" and year("birthDate") > "1960") # 남자이고 1960년 후에 태어난 사람들 row를 상위 5개 출력
test1.show(5)
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">+---------+
# firstName|
# +---------+
#        An|
#     Quyen|
#   Coralie|
#    Terrie|
#  Chassidy|
# +---------+
# only showing top 5 rows
#
# </div>

# %%
peopleDF.select("firstName", year("birthDate")).filter("'gender'='M'" and year("birthDate") > "1960").show(10) # 남자이고 1960년 후에 태어난 사람들 row를 상위 10개 출력
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">+---------+---------------+
# firstName|year(birthDate)|
# +---------+---------------+
#        An|           1992|
#     Quyen|           1970|
#   Coralie|           1990|
#    Terrie|           1980|
#  Chassidy|           1990|
#      Geri|           1970|
#    Patria|           1985|
#    Terese|           1967|
#      Wava|           1963|
#    Sophie|           1979|
# +---------+---------------+
# only showing top 10 rows
#
# </div>

# %%
peopleDF.groupBy("gender").count().show() # 성별로 group화 하여 각 성별 별 인원수를 구함
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">+------+-------+
# gender|  count|
# +------+-------+
#      F|5187302|
#      M|4812698|
# +------+-------+
#
# </div>

# %%
peopleDF.groupBy("firstName").count().orderBy("firstName").show(5) # 이름순으로 정렬 후, 이름별로 그룹화하여 인원수를 구한다.
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">+---------+-----+
# firstName|count|
# +---------+-----+
#     Aaron| 4020|
#     Abbey| 1273|
#     Abbie| 1288|
#      Abby| 1235|
#     Abdul| 3966|
# +---------+-----+
# only showing top 5 rows
#
# </div>

# %%
peopleDF.groupBy("firstName").count().orderBy("count", ascending=False).show(5) #내림차순
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">+---------+-----+
# firstName|count|
# +---------+-----+
#    Sammie| 5462|
#     Daryl| 5442|
#    Bobbie| 5432|
#       Lee| 5411|
#      Troy| 5408|
# +---------+-----+
# only showing top 5 rows
#
# </div>

# %%
peopleDF.groupBy("firstName").count().orderBy("count").show(5) # 오름차순
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">+---------+-----+
# firstName|count|
# +---------+-----+
#  Marylynn| 1150|
#     Verna| 1154|
#   Carlena| 1159|
#       Thi| 1162|
#    Tennie| 1162|
# +---------+-----+
# only showing top 5 rows
#
# </div>

# %%
from pyspark.sql.functions import col
peopleDF.groupBy("firstName").count().filter(col("count") > "5430").orderBy("count", ascending=False).show(6)
# filter("'count' > '5430'") 안됨
# filter("count" > 5430) 안됨
# 아마도 count연산으로 생긴 컬럼이기 때문에, 기존에 있던 컬럼이 아니라서 그런듯 함
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">+---------+-----+
# firstName|count|
# +---------+-----+
#    Sammie| 5462|
#     Daryl| 5442|
#    Bobbie| 5432|
# +---------+-----+
#
# </div>

# %%
peopleDF\
        .select("firstname", 'lastName')\
        .filter("gender='M'")\
        .show(5)
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">+---------+--------+
# firstname|lastName|
# +---------+--------+
#    Jasper|Neubigin|
#    Robert| Kipling|
#     Abdul|  Pachta|
#     Earle|Gieraths|
#    Mickey|  Wotton|
# +---------+--------+
# only showing top 5 rows
#
# </div>

# %%
testDF1 = peopleDF\
          .select("firstName", "lastName", "birthDate")\
          .filter("gender='M'")
testDF1.show(5)
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">+---------+--------+-------------------+
# firstName|lastName|          birthDate|
# +---------+--------+-------------------+
#    Jasper|Neubigin|1961-02-20 05:00:00|
#    Robert| Kipling|1986-01-02 05:00:00|
#     Abdul|  Pachta|1956-01-28 05:00:00|
#     Earle|Gieraths|1958-04-17 05:00:00|
#    Mickey|  Wotton|1976-08-29 04:00:00|
# +---------+--------+-------------------+
# only showing top 5 rows
#
# </div>

# %%
from pyspark.sql.functions import year
testDF2 = testDF1\
          .filter(year("birthDate") > "1990")
testDF2.show(5)
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">+---------+---------+-------------------+
# firstName| lastName|          birthDate|
# +---------+---------+-------------------+
#    Theron|    Aplin|1995-03-16 05:00:00|
#  Valentin|  Yakunin|1999-04-06 04:00:00|
#    Emmett|    Grgic|1991-04-22 04:00:00|
#    Nelson|     Kelf|1995-08-17 04:00:00|
#     Sonny|Kornousek|1994-11-04 05:00:00|
# +---------+---------+-------------------+
# only showing top 5 rows
#
# </div>

# %%
display(testDF2)
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>firstName</th><th>lastName</th><th>birthDate</th></tr></thead><tbody><tr><td>Theron</td><td>Aplin</td><td>1995-03-16T05:00:00.000+0000</td></tr><tr><td>Valentin</td><td>Yakunin</td><td>1999-04-06T04:00:00.000+0000</td></tr><tr><td>Emmett</td><td>Grgic</td><td>1991-04-22T04:00:00.000+0000</td></tr><tr><td>Nelson</td><td>Kelf</td><td>1995-08-17T04:00:00.000+0000</td></tr><tr><td>Sonny</td><td>Kornousek</td><td>1994-11-04T05:00:00.000+0000</td></tr><tr><td>Lucio</td><td>Orpwood</td><td>1993-10-28T04:00:00.000+0000</td></tr><tr><td>Burl</td><td>Fronks</td><td>1996-04-20T04:00:00.000+0000</td></tr><tr><td>Marco</td><td>Mueller</td><td>1998-12-23T05:00:00.000+0000</td></tr><tr><td>Loyd</td><td>Gerish</td><td>1998-09-27T04:00:00.000+0000</td></tr><tr><td>Mar
><td>24</td></tr><tr><td>1969</td><td>32</td></tr><tr><td>1970</td><td>31</td></tr><tr><td>1971</td><td>15</td></tr><tr><td>1972</td><td>24</td></tr><tr><td>1973</td><td>29</td></tr><tr><td>1974</td><td>23</td></tr><tr><td>1975</td><td>28</td></tr><tr><td>1976</td><td>18</td></tr><tr><td>1977</td><td>33</td></tr><tr><td>1978</td><td>17</td></tr><tr><td>1979</td><td>23</td></tr><tr><td>1980</td><td>26</td></tr><tr><td>1981</td><td>30</td></tr><tr><td>1982</td><td>22</td></tr><tr><td>1983</td><td>32</td></tr><tr><td>1984</td><td>22</td></tr><tr><td>1985</td><td>19</td></tr><tr><td>1986</td><td>29</td></tr><tr><td>1987</td><td>26</td></tr><tr><td>1988</td><td>26</td></tr><tr><td>1989</td><td>25</td></tr><tr><td>1990</td><td>32</td></tr><tr><td>1991</td><td>25</td></tr><tr><td>1992</td><td>29</td></tr><tr><td>1993</td><td>39</td></tr><tr><td>1994</td><td>27</td></tr><tr><td>1995</td><td>28</td></tr><tr><td>1996</td><td>35</td></tr><tr><td>1997</td><td>32</td></tr><tr><td>1998</td><td>27</td></tr><tr><td>1999</td><td>25</td></tr><tr><td>2000</td><td>1</td></tr></tbody></table></div>

# %%
dordonDF = peopleDF.\
            select(year("birthDate").alias("birthYear"), "firstName").\
            filter((col("firstName") == 'Donna') | (col("firstName") == 'Dorothy')).\
            filter("gender == 'F'").\
            groupBy('birthYear', 'firstName').\
            count().\
            orderBy('birthYear').\
            show(5)\
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">+---------+---------+-----+
# birthYear|firstName|count|
# +---------+---------+-----+
#      1952|  Dorothy|   21|
#      1952|    Donna|   24|
#      1953|    Donna|   37|
#      1953|  Dorothy|   38|
#      1954|  Dorothy|   29|
# +---------+---------+-----+
# only showing top 5 rows
#
# </div>

# %%
dordonDF = (peopleDF.
            select(year("birthDate").alias("birthYear"), "firstName").
            filter((col("firstName") == 'Donna') | (col("firstName") == 'Dorothy')).
            filter("gender == 'F'").
            filter( year("birthDate") > 1990 ). # year()를 비교할 시 1990 또는 "1990" 둘다 가능하다            
            groupBy('birthYear', 'firstName').
            count().
            orderBy('birthYear')
)
display(dordonDF)
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>birthYear</th><th>firstName</th><th>count</th></tr></thead><tbody><tr><td>1991</td><td>Donna</td><td>27</td></tr><tr><td>1991</td><td>Dorothy</td><td>25</td></tr><tr><td>1992</td><td>Dorothy</td><td>39</td></tr><tr><td>1992</td><td>Donna</td><td>30</td></tr><tr><td>1993</td><td>Donna</td><td>22</td></tr><tr><td>1993</td><td>Dorothy</td><td>28</td></tr><tr><td>1994</td><td>Donna</td><td>26</td></tr><tr><td>1994</td><td>Dorothy</td><td>21</td></tr><tr><td>1995</td><td>Dorothy</td><td>26</td></tr><tr><td>1995</td><td>Donna</td><td>33</td></tr><tr><td>1996</td><td>Dorothy</td><td>19</td></tr><tr><td>1996</td><td>Donna</td><td>23</td></tr><tr><td>1997</td><td>Donna</td><td>36</td></tr><tr><td>1997</td><td>Dorothy</td><td>24</td></tr><tr><td>1998</td><td>Donna</td><td>28</td></tr><tr><td>1998</td><td>Dorothy</td><td>33</td></tr><tr><td>1999</td><td>Donna</td><td>22</td></tr><tr><td>1999</td><td>Dorothy</td><td>25</td></tr><tr><td>2000</td><td>Dorothy</td><td>4</td></tr><tr><td>2000</td><td>Donna</td><td>2</td></tr></tbody></table></div>

# %%
peopleDF.createOrReplaceTempView("People10M")
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
sp
td><td>1994</td></tr><tr><td>Moriah</td><td>Ilana</td><td>Johncey</td><td>1996</td></tr><tr><td>Jetta</td><td>Annelle</td><td>Greave</td><td>1992</td></tr><tr><td>Anya</td><td>Machelle</td><td>Alben</td><td>1998</td></tr><tr><td>Catalina</td><td>Pilar</td><td>Scolli</td><td>1992</td></tr><tr><td>Frances</td><td>Ronna</td><td>Worssam</td><td>1999</td></tr><tr><td>Dia</td><td>Sherlene</td><td>Bromehed</td><td>1993</td></tr><tr><td>Jodie</td><td>Janina</td><td>Angel</td><td>1993</td></tr><tr><td>Kristian</td><td>Sheilah</td><td>Bowcock</td><td>1994</td></tr><tr><td>Avril</td><td>Santa</td><td>Bruggen</td><td>1998</td></tr><tr><td>Kayce</td><td>Neta</td><td>Beadles</td><td>1997</td></tr><tr><td>Pia</td><td>Eldora</td><td>Harverson</td><td>1991</td></tr><tr><td>Yolando</td><td>Harriett</td><td>Sorley</td><td>1999</td></tr><tr><td>Shery</td><td>Ivey</td><td>Lawler</td><td>1997</td></tr><tr><td>Melda</td><td>Lenita</td><td>Storre</td><td>1992</td></tr><tr><td>Keturah</td><td>Mirtha</td><td>Krauze</td><td>1996</td></tr><tr><td>Nichelle</td><td>Ashleigh</td><td>Lemmen</td><td>1991</td></tr><tr><td>Letisha</td><td>Echo</td><td>Livesley</td><td>1995</td></tr><tr><td>Fannie</td><td>Darcy</td><td>Taffrey</td><td>1997</td></tr><tr><td>Tyni ...

# %%
womenBornAfter1990DF.createOrReplaceTempView('womenBornAfter1990')
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
# %sql
select count(*) from womenBornAfter1990 where firstName = "Mary"
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>count(1)</th></tr></thead><tbody><tr><td>268</td></tr></tbody></table></div>

# %%
from pyspark.sql.functions import count, desc

top10FemaleFirstNamesDF = (peopleDF
                          .select("firstName")
                          .filter("gender == 'F'")
                          .groupBy("firstName")
                          .agg(count(col('firstName')).alias('total'))
                          .orderBy((desc('total')))
                          .limit(10)
                          )
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
top10FemaleFirstNamesDF = top10FemaleFirstNamesDF.orderBy("firstName")
display(top10FemaleFirstNamesDF)
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>firstName</th><th>total</th></tr></thead><tbody><tr><td>Alesha</td><td>1368</td></tr><tr><td>Alice</td><td>1384</td></tr><tr><td>Bridgette</td><td>1373</td></tr><tr><td>Cristen</td><td>1375</td></tr><tr><td>Jacquelyn</td><td>1381</td></tr><tr><td>Katherin</td><td>1373</td></tr><tr><td>Lashell</td><td>1387</td></tr><tr><td>Louie</td><td>1382</td></tr><tr><td>Lucille</td><td>1384</td></tr><tr><td>Sharyn</td><td>1394</td></tr></tbody></table></div>

# %%
top10FemaleFirstNamesDF.createOrReplaceTempView("Top10FemaleFirstNamesDF")
resultDF = spark.sql("select * from Top10FemaleFirstNamesDF order by firstName")
display(resultDF)
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>firstName</th><th>total</th></tr></thead><tbody><tr><td>Alesha</td><td>1368</td></tr><tr><td>Alice</td><td>1384</td></tr><tr><td>Bridgette</td><td>1373</td></tr><tr><td>Cristen</td><td>1375</td></tr><tr><td>Jacquelyn</td><td>1381</td></tr><tr><td>Katherin</td><td>1373</td></tr><tr><td>Lashell</td><td>1387</td></tr><tr><td>Louie</td><td>1382</td></tr><tr><td>Lucille</td><td>1384</td></tr><tr><td>Sharyn</td><td>1394</td></tr></tbody></table></div>
